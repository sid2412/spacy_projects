# %%
from preprocess_3 import preprocess
label_values, train_data, valid_texts, valid_labels, test_texts, test_labels = preprocess('consumer_complaints.csv', n_rows=5000)
# Out:
# Reading data..
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (5,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Cleaning text..
#
# Text cleaning complete
#
# Selected 5000 rows for training
#
# Splitting dataset into train, valid and test sets..
#
# Shape of train_X: (3612,)
# Shape of train_y: (3612,)
#
# Shape of test_X: (750,)
# Shape of train_y: (3612,)
#
# Shape of valid_X: (638,)
# Shape of valid_y: (638,)
#
# Data is now ready to be tained

# %%
from train_spacy_6 import train_spacy
train_spacy(label_values, train_data, valid_texts, valid_labels, 10, 'ensemble', 0.3, 3e-3, 'trial_01')
# Out:
# Model loading complete
#
# Training the model..
#
# Iteration: 1
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                          precision    recall  f1-score   support
#
# Bank account or service       0.61      0.77      0.68        52
#           Consumer Loan       0.75      0.18      0.29        34
#             Credit card       0.56      0.64      0.60        70
#        Credit reporting       0.83      0.72      0.77       103
#         Debt collection       0.78      0.86      0.82       182
#         Money transfers       0.00      0.00      0.00         7
#                Mortgage       0.93      0.93      0.93       149
# ...

# %%
from evaluate_3 import evaluate
evaluate(test_texts, test_labels, 'trial_01')
# Out:
# Model loading complete
#                          precision    recall  f1-score   support
#
# Bank account or service       0.73      0.67      0.70        60
#           Consumer Loan       0.46      0.40      0.43        40
#             Credit card       0.64      0.78      0.70        82
#        Credit reporting       0.82      0.77      0.79       122
#         Debt collection       0.80      0.85      0.83       213
#         Money transfers       0.60      0.38      0.46         8
#                Mortgage       0.92      0.95      0.94       176
# Other financial service       0.00      0.00      0.00         1
#             Payday loan       0.00      0.00      0.00        10
#            Prepaid card       0.00      0.00      0.00         5
#            Student loan       0.73      0.73      0.73        33
#
#                accuracy                           0.79       750
#               macro avg       0.52      0.50      0.51       750
# ...
