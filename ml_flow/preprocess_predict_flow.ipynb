# %% [markdown]
# # Pipeline for making predictions on a csv data file
# - preprocess csv data into spacy format
# - Evaluate the test set on the pre-saved model
# - make predictions on the test set

# %% [markdown]
# ### Preprocess

# %%
# preprocess data into spacy format
from _3_preprocess_df import preprocess_df
label_values, test_data, test_texts, test_labels = preprocess_df('../consumer_complaints.csv', 
                                                                    n_rows=1000)
# Out:
# Reading data..
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (5,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Cleaning text..
#
# Text cleaning complete
#
# Selected 1000 rows for training
#
# Converting dataframe into series..
#
# Shape of train_X: (1000,)
# Shape of train_y: (1000,)
#
# Converting data to spacy format
#
# Data is now ready to be trained

# %% [markdown]
# ### Evaluate

# %%
from _6_evaluate import evaluate
evaluate(test_texts, test_labels, '../trial_01', label_values)
# Out:
# Model loading complete
# Normalized confusion matrix
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                          precision    recall  f1-score   support
#
# Bank account or service       0.84      0.87      0.86        78
#           Consumer Loan       0.84      0.82      0.83        57
#             Credit card       0.80      0.92      0.85       120
#        Credit reporting       0.92      0.93      0.93       143
#         Debt collection       0.91      0.90      0.91       283
#         Money transfers       1.00      0.65      0.79        17
#                Mortgage       0.98      0.98      0.98       233
# ...

# %% [markdown]
# ### Make predictions

# %%
from _7_make_predictions import make_predictions
make_predictions('../trial_01', test_texts[15])
# Out:
# The model predicts: Debt collection

# %%
from _7_make_predictions import comp_pred
comp_pred('../trial_01', test_texts, test_labels, 15)
# Out:
# Text:
# ...
